# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/colab/2. CNN
# Out:
# /content/drive/MyDrive/colab/2. CNN

# %% [markdown]
# ## Advanced Keras application

# %%
from glob import glob
glob('animal/*')
# Out:
# ['animal/elephant.jpg',
#  'animal/giraffe.jpg',
#  'animal/crow.jpg',
#  'animal/magpie.jpg',
#  'animal/ginipig.webp',
#  'animal/jaguar.webp',
#  'animal/cheetah.jpg',
#  'animal/puma.webp',
#  'animal/cougar.jpg',
#  'animal/rabbit.jpg']

# %%
animal = []
for i in glob('animal/*') :
    i = i.split('/')[1]
    animal.append(i.split('.')[0])
animal
# Out:
# ['elephant',
#  'giraffe',
#  'crow',
#  'magpie',
#  'ginipig',
#  'jaguar',
#  'cheetah',
#  'puma',
#  'cougar',
#  'rabbit']

# %% [markdown]
# ### VGGNet16

# %%
from tensorflow.keras.applications.vgg16 import VGG16, decode_predictions

# %%
vgg16 = VGG16()

vgg16_list = []
for i in glob('animal/*') :
    img = np.array(Image.open(i).resize((224, 224)))
    yhat = vgg16.predict(img.reshape(-1, 224, 224, 3))
    label = decode_predictions(yhat)
    vgg16_list.append(label[0][0][1])
print(vgg16_list)
# Out:
# ['African_elephant', 'hook', 'house_finch', 'albatross', 'hare', 'leopard', 'cheetah', 'coyote', 'cougar', 'hare']

# %% [markdown]
# ### VGGNet19

# %%
from tensorflow.keras.applications.vgg19 import VGG19, decode_predictions
import cv2
vgg19 = VGG19()

# %%
vgg19_list = []
for i in glob('animal/*') :
    img = cv2.imread(i)
    img = cv2.resize(img, (224, 224))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    yhat = vgg16.predict(img.reshape(-1, 224, 224, 3))
    label = decode_predictions(yhat)
    vgg19_list.append(label[0][0][1])
print(vgg19_list)
# Out:
# ['African_elephant', 'knot', 'house_finch', 'albatross', 'guinea_pig', 'leopard', 'cheetah', 'coyote', 'cougar', 'hare']

# %% [markdown]
# ### ResNet 50

# %%
from tensorflow.keras.applications.resnet import ResNet50, decode_predictions
resnet50 = ResNet50()
# Out:
# ...
# 102973440/102967424 [==============================] - 1s 0us/step

# %%
resnet50_list = []
for i in glob('animal/*') :
    img = np.array(Image.open(i).resize((224, 224)))
    yhat = resnet50.predict(img.reshape(-1, 224, 224, 3))
    label = decode_predictions(yhat)
    resnet50_list.append(label[0][0][1])
print(resnet50_list)
# Out:
# ['African_elephant', 'electric_guitar', 'house_finch', 'magpie', 'skunk', 'jaguar', 'cheetah', 'cougar', 'cougar', 'wood_rabbit']

# %% [markdown]
# ### ResNet 101

# %%
from tensorflow.keras.applications.resnet import ResNet101, decode_predictions
resnet101 = ResNet101()
# Out:
# ...
# 179650560/179648224 [==============================] - 3s 0us/step

# %%
resnet101_list = []
for i in glob('animal/*') :
    img = np.array(Image.open(i).resize((224, 224)))
    yhat = resnet101.predict(img.reshape(-1, 224, 224, 3))
    label = decode_predictions(yhat)
    resnet101_list.append(label[0][0][1])
print(resnet101_list)
# Out:
# ['African_elephant', 'gazelle', 'kite', 'magpie', 'guinea_pig', 'cheetah', 'cheetah', 'cougar', 'cougar', 'hare']

# %% [markdown]
# ### Comparing

# %%
import pandas as pd

df = pd.DataFrame({
    'Original' : animal,
    'VGG16' : vgg16_list,
    'VGG19' : vgg19_list,
    'ResNet 50' : resnet50_list,
    'ResNet 101' : resnet101_list
})
df
# Out:
#    Original             VGG16  ...         ResNet 50        ResNet 101
# 0  elephant  African_elephant  ...  African_elephant  African_elephant
# 1   giraffe              hook  ...   electric_guitar           gazelle
# 2      crow       house_finch  ...       house_finch              kite
# 3    magpie         albatross  ...            magpie            magpie
# 4   ginipig              hare  ...             skunk        guinea_pig
# 5    jaguar           leopard  ...            jaguar           cheetah
# 6   cheetah           cheetah  ...           cheetah           cheetah
# 7      puma            coyote  ...            cougar            cougar
# 8    cougar            cougar  ...            cougar            cougar
# 9    rabbit              hare  ...       wood_rabbit              hare
#
# [10 rows x 5 columns]
