# %% [markdown]
# # Text generating by using LSTM

# %% [markdown]
# ## New York Times Comments

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
seed = 2021
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

# %%
df = pd.read_csv('ArticlesApril2018.csv', encoding = 'latin1')
df

# %% [markdown]
# ### Preprocessing

# %%
df.columns

# %%
df.headline.isnull().sum()

# %%
headlines = [i for i in df.headline.values]
len(headlines)

# %%
headlines[:5]

# %% [markdown]
# #### Delete noise datas

# %%
headlines = [i for i in headlines if i != 'Unknown']
len(headlines)

# %%
#### Delete punctuations and transfer to small letter

# %%
from string import punctuation
punctuation

# %%
def prepro(s) :
    s = s.encode('utf8').decode('ascii', 'ignore')
    return ''.join(i for i in s if i not in punctuation).lower()

# %%
headlines = [prepro(s) for s in headlines]
headlines[:5]

# %% [markdown]
# #### Generating word set and checking its size

# %%
t = Tokenizer()
t.fit_on_texts(headlines)
vocab_size = len(t.word_index) + 1
vocab_size

# %% [markdown]
# #### Sequence for learning

# %%
sequences = []
for i in headlines :
    encoded = t.texts_to_sequences([i])[0]
    for j in range(1, len(encoded)) :
        s = encoded[: j + 1]
        sequences.append(s)
sequences[:5]

# %%
max_len = max(len(s) for s in sequences)
max_len

# %%
sequences = pad_sequences(sequences, maxlen = max_len, padding = 'pre')
sequences[:5]

# %%
X = sequences[:, : -1]
y = sequences[:, -1]
Y = to_categorical(y)
X.shape, Y.shape

# %% [markdown]
# ### Processing
#
# - Embedding
# - LSTM

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %% [markdown]
# #### Embedding Vector 10, LSTM size 128

# %%
model = Sequential([
    Embedding(vocab_size, 10, input_length = max_len -1),
    LSTM(128),
    Dense(vocab_size, activation = 'softmax')
])
model.summary()

# %%
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
history = model.fit(X, Y, epochs = 200, verbose = 2)
# Out:
# Epoch 1/200
# 244/244 - 3s - loss: 0.2641 - accuracy: 0.9163
# Epoch 2/200
# 244/244 - 3s - loss: 0.2615 - accuracy: 0.9161
# Epoch 3/200
# 244/244 - 3s - loss: 0.2612 - accuracy: 0.9170
# Epoch 4/200
# 244/244 - 3s - loss: 0.2622 - accuracy: 0.9161
# Epoch 5/200
# 244/244 - 3s - loss: 0.2617 - accuracy: 0.9176
# Epoch 6/200
# 244/244 - 3s - loss: 0.2618 - accuracy: 0.9167
# Epoch 7/200
# 244/244 - 3s - loss: 0.2713 - accuracy: 0.9157
# Epoch 8/200
# 244/244 - 3s - loss: 0.2668 - accuracy: 0.9166
# Epoch 9/200
# 244/244 - 3s - loss: 0.2765 - accuracy: 0.9154
# Epoch 10/200
# 244/244 - 3s - loss: 0.2652 - accuracy: 0.9164
# Epoch 11/200
# 244/244 - 3s - loss: 0.2601 - accuracy: 0.9152
# Epoch 12/200
# 244/244 - 3s - loss: 0.2619 - accuracy: 0.9171
# Epoch 13/200
# 244/244 - 3s - loss: 0.2590 - accuracy: 0.9190
# Epoch 14/200
# 244/244 - 3s - loss: 0.2594 - accuracy: 0.9152
# Epoch 15/200
# 244/244 - 3s - loss: 0.2597 - accuracy: 0.9168
# Epoch 16/200
# 244/244 - 3s - loss: 0.2588 - accuracy: 0.9176
# Epoch 17/200
# 244/244 - 3s - loss: 0.2586 - accuracy: 0.9166
# Epoch 18/200
# 244/244 - 3s - loss: 0.2501 - accuracy: 0.9170
# Epoch 94/200
# 244/244 - 3s - loss: 0.2516 - accuracy: 0.9157
# Epoch 95/200
# 244/244 - 3s - loss: 0.2507 - accuracy: 0.9167
# Epoch 96/200
# 244/244 - 3s - loss: 0.2514 - accuracy: 0.9162
# Epoch 97/200
# 244/244 - 3s - loss: 0.2519 - accuracy: 0.9161
# Epoch 98/200
# 244/244 - 3s - loss: 0.2515 - accuracy: 0.9154
# Epoch 99/200
# 244/244 - 3s - loss: 0.2498 - accuracy: 0.9173
# Epoch 100/200
# 244/244 - 3s - loss: 0.2506 - accuracy: 0.9167
# Epoch 101/200
# 244/244 - 3s - loss: 0.2516 - accuracy: 0.9158
# Epoch 102/200
# 244/244 - 3s - loss: 0.2507 - accuracy: 0.9159
# Epoch 103/200
# 244/244 - 3s - loss: 0.2510 - accuracy: 0.9164
# Epoch 104/200
# 244/244 - 3s - loss: 0.2515 - accuracy: 0.9172
# Epoch 105/200
# 244/244 - 3s - loss: 0.2499 - accuracy: 0.9186
# Epoch 106/200
# 244/244 - 3s - loss: 0.2528 - accuracy: 0.9176
# Epoch 107/200
# 244/244 - 3s - loss: 0.2519 - accuracy: 0.9168
# Epoch 108/200
# 244/244 - 3s - loss: 0.2697 - accuracy: 0.9117
# Epoch 109/200
# 244/244 - 3s - loss: 0.2748 - accuracy: 0.9113
# Epoch 110/200
# 244/244 - 3s - loss: 0.2565 - accuracy: 0.9149
# Epoch 111/200
# 244/244 - 3s - loss: 0.2519 - accuracy: 0.9172
# Epoch 112/200
# 244/244 - 3s - loss: 0.2503 - accuracy: 0.9172
# Epoch 113/200
# 244/244 - 3s - loss: 0.2497 - accuracy: 0.9163
# Epoch 114/200
# 244/244 - 3s - loss: 0.2496 - accuracy: 0.9179
# Epoch 115/200
# 244/244 - 3s - loss: 0.2495 - accuracy: 0.9164
# Epoch 116/200
# 244/244 - 3s - loss: 0.2496 - accuracy: 0.9159
# Epoch 117/200
# 244/244 - 3s - loss: 0.2501 - accuracy: 0.9163
# Epoch 118/200
# 244/244 - 3s - loss: 0.2494 - accuracy: 0.9164
# Epoch 119/200
# 244/244 - 3s - loss: 0.2496 - accuracy: 0.9152
# Epoch 120/200
# 244/244 - 3s - loss: 0.2499 - accuracy: 0.9163
# Epoch 121/200
# 244/244 - 3s - loss: 0.2496 - accuracy: 0.9166
# Epoch 122/200
# 244/244 - 3s - loss: 0.2501 - accuracy: 0.9154
# Epoch 123/200
# 244/244 - 3s - loss: 0.2494 - accuracy: 0.9163
# Epoch 124/200
# 244/244 - 3s - loss: 0.2493 - accuracy: 0.9164
# Epoch 125/200
# 244/244 - 3s - loss: 0.2497 - accuracy: 0.9154
# Epoch 126/200
# 244/244 - 3s - loss: 0.2503 - accuracy: 0.9171
# Epoch 127/200
# 244/244 - 3s - loss: 0.2501 - accuracy: 0.9166
# Epoch 128/200
# 244/244 - 3s - loss: 0.2504 - accuracy: 0.9155
# Epoch 129/200
# 244/244 - 3s - loss: 0.2501 - accuracy: 0.9167
# Epoch 130/200
# 244/244 - 3s - loss: 0.2596 - accuracy: 0.9155
# Epoch 131/200
# 244/244 - 3s - loss: 0.2709 - accuracy: 0.9125
# Epoch 132/200
# 244/244 - 3s - loss: 0.2562 - accuracy: 0.9161
# Epoch 133/200
# 244/244 - 3s - loss: 0.2593 - accuracy: 0.9145
# Epoch 134/200
# 244/244 - 3s - loss: 0.2511 - accuracy: 0.9166
# Epoch 135/200
# 244/244 - 3s - loss: 0.2494 - accuracy: 0.9161
# Epoch 136/200
# 244/244 - 3s - loss: 0.2484 - accuracy: 0.9171
# Epoch 137/200
# 244/244 - 3s - loss: 0.2487 - accuracy: 0.9171
# Epoch 138/200
# 244/244 - 3s - loss: 0.2484 - accuracy: 0.9179
# Epoch 139/200
# 244/244 - 3s - loss: 0.2491 - accuracy: 0.9159
# Epoch 140/200
# 244/244 - 3s - loss: 0.2486 - accuracy: 0.9176
# Epoch 141/200
# 244/244 - 3s - loss: 0.2488 - accuracy: 0.9173
# Epoch 142/200
# 244/244 - 3s - loss: 0.2492 - accuracy: 0.9168
# Epoch 143/200
# 244/244 - 3s - loss: 0.2487 - accuracy: 0.9184
# Epoch 144/200
# 244/244 - 3s - loss: 0.2491 - accuracy: 0.9166
# Epoch 145/200
# 244/244 - 3s - loss: 0.2488 - accuracy: 0.9166
# Epoch 146/200
# 244/244 - 3s - loss: 0.2493 - accuracy: 0.9164
# Epoch 147/200
# 244/244 - 3s - loss: 0.2493 - accuracy: 0.9170
# Epoch 148/200
# 244/244 - 3s - loss: 0.2489 - accuracy: 0.9173
# Epoch 149/200
# 244/244 - 3s - loss: 0.2490 - accuracy: 0.9168
# Epoch 150/200
# 244/244 - 3s - loss: 0.2491 - accuracy: 0.9170
# Epoch 151/200
# 244/244 - 3s - loss: 0.2491 - accuracy: 0.9170
# Epoch 152/200
# 244/244 - 3s - loss: 0.2490 - accuracy: 0.9163
# Epoch 153/200
# 244/244 - 3s - loss: 0.2489 - accuracy: 0.9181
# Epoch 154/200
# 244/244 - 3s - loss: 0.2496 - accuracy: 0.9154
# Epoch 155/200
# 244/244 - 3s - loss: 0.2492 - accuracy: 0.9157
# Epoch 156/200
# 244/244 - 3s - loss: 0.2604 - accuracy: 0.9145
# Epoch 157/200
# 244/244 - 3s - loss: 0.2682 - accuracy: 0.9130
# Epoch 158/200
# 244/244 - 3s - loss: 0.2563 - accuracy: 0.9164
# Epoch 159/200
# 244/244 - 3s - loss: 0.2489 - accuracy: 0.9175
# Epoch 160/200
# 244/244 - 3s - loss: 0.2476 - accuracy: 0.9176
# Epoch 161/200
# 244/244 - 3s - loss: 0.2481 - accuracy: 0.9158
# Epoch 162/200
# 244/244 - 3s - loss: 0.2483 - accuracy: 0.9170
# Epoch 163/200
# 244/244 - 3s - loss: 0.2480 - accuracy: 0.9163
# Epoch 164/200
# 244/244 - 3s - loss: 0.2475 - accuracy: 0.9180
# Epoch 165/200
# 244/244 - 3s - loss: 0.2483 - accuracy: 0.9163
# Epoch 166/200
# 244/244 - 3s - loss: 0.2482 - accuracy: 0.9168
# Epoch 167/200
# 244/244 - 3s - loss: 0.2482 - accuracy: 0.9159
# Epoch 168/200
# 244/244 - 3s - loss: 0.2475 - accuracy: 0.9175
# Epoch 169/200
# 244/244 - 3s - loss: 0.2475 - accuracy: 0.9161
# Epoch 170/200
# 244/244 - 3s - loss: 0.2485 - accuracy: 0.9164
# Epoch 171/200
# 244/244 - 3s - loss: 0.2477 - accuracy: 0.9182
# Epoch 172/200
# 244/244 - 3s - loss: 0.2484 - accuracy: 0.9171
# Epoch 173/200
# 244/244 - 3s - loss: 0.2483 - accuracy: 0.9182
# Epoch 174/200
# 244/244 - 3s - loss: 0.2484 - accuracy: 0.9155
# Epoch 175/200
# 244/244 - 3s - loss: 0.2479 - accuracy: 0.9166
# Epoch 176/200
# 244/244 - 3s - loss: 0.2485 - accuracy: 0.9158
# Epoch 177/200
# 244/244 - 3s - loss: 0.2481 - accuracy: 0.9171
# Epoch 178/200
# 244/244 - 3s - loss: 0.2484 - accuracy: 0.9171
# Epoch 179/200
# 244/244 - 3s - loss: 0.2484 - accuracy: 0.9159
# Epoch 180/200
# 244/244 - 3s - loss: 0.2482 - accuracy: 0.9166
# Epoch 181/200
# 244/244 - 3s - loss: 0.2488 - accuracy: 0.9163
# Epoch 182/200
# 244/244 - 3s - loss: 0.2482 - accuracy: 0.9185
# Epoch 183/200
# 244/244 - 3s - loss: 0.2493 - accuracy: 0.9163
# Epoch 184/200
# 244/244 - 3s - loss: 0.2607 - accuracy: 0.9146
# Epoch 185/200
# 244/244 - 3s - loss: 0.2663 - accuracy: 0.9118
# Epoch 186/200
# 244/244 - 3s - loss: 0.2578 - accuracy: 0.9146
# Epoch 187/200
# 244/244 - 3s - loss: 0.2501 - accuracy: 0.9173
# Epoch 188/200
# 244/244 - 3s - loss: 0.2479 - accuracy: 0.9167
# Epoch 189/200
# 244/244 - 3s - loss: 0.2471 - accuracy: 0.9168
# Epoch 190/200
# 244/244 - 3s - loss: 0.2467 - accuracy: 0.9176
# Epoch 191/200
# 244/244 - 3s - loss: 0.2473 - accuracy: 0.9170
# Epoch 192/200
# 244/244 - 3s - loss: 0.2473 - accuracy: 0.9163
# Epoch 193/200
# 244/244 - 3s - loss: 0.2474 - accuracy: 0.9161
# Epoch 194/200
# 244/244 - 3s - loss: 0.2472 - accuracy: 0.9180
# Epoch 195/200
# 244/244 - 3s - loss: 0.2472 - accuracy: 0.9163
# Epoch 196/200
# 244/244 - 3s - loss: 0.2471 - accuracy: 0.9170
# Epoch 197/200
# 244/244 - 3s - loss: 0.2478 - accuracy: 0.9162
# Epoch 198/200
# 244/244 - 3s - loss: 0.2478 - accuracy: 0.9172
# Epoch 199/200
# 244/244 - 3s - loss: 0.2479 - accuracy: 0.9164
# Epoch 200/200
# 244/244 - 3s - loss: 0.2477 - accuracy: 0.9181

# %% [markdown]
# #### Verify model

# %%
from my_util import sentence_generation

# %%
print(sentence_generation(model, t, max_len, 'i', 10))
print(sentence_generation(model, t, max_len, 'epa', 10))
print(sentence_generation(model, t, max_len, 'former', 10))
# Out:
# i want to be rich and im not sorry president scott
# epa sheriff indulged pruitt as security spending mounted behind the streets
# former nfl cheerleaders settlement offer 1 and a meeting with goodell
